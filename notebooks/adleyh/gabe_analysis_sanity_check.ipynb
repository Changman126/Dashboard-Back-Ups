# %%
import pandas as pd
import numpy as np
import vertica_python
import os
import seaborn as sns

# %%
# %matplotlib inline

# %%
username = os.getenv('VERTICA_USERNAME')
password = os.getenv('VERTICA_PASSWORD')
conn_info = {'host': 'warehouse.analytics.edx.org',
             'port': 5433,
             'user': username,
             'password': password,
             'database': 'warehouse',
             'read_timeout': 600,
             'unicode_error': 'strict',
             'ssl': False}

# %%
query = """
SELECT
    pacing_type,
    CASE
        WHEN duc.first_verified_enrollment_time IS NULL
            THEN TRUE
        ELSE DATEDIFF('minute', duc.first_enrollment_time, duc.first_verified_enrollment_time) > 60
    END AS verified_after_enrollment,
    CASE
        WHEN duc.first_enrollment_time > (ca.course_start_date + 7) THEN 'After'
        WHEN duc.first_enrollment_time > ca.course_start_date THEN 'First Week'
        WHEN (duc.first_enrollment_time + 7) > ca.course_start_date THEN 'One Week Before'
        ELSE '> 1 Week Before'
    END AS enrolled_before_course_start,
    CASE
        WHEN c.course_partner = 'Microsoft' THEN 'Microsoft'
        ELSE 'Not Microsoft'
    END AS is_microsoft,
    CASE
        WHEN c.course_seat_price :: INT BETWEEN 0 AND 25 THEN '1) 0 < price <= 25'
        WHEN c.course_seat_price :: INT BETWEEN 26 AND 75 THEN '2) 25 < price <= 75'
        WHEN c.course_seat_price :: INT BETWEEN 76 AND 150 THEN '3) 75 < price <= 150'
        WHEN c.course_seat_price :: INT > 150 THEN '4) 150 < price'
    END AS price,
    CASE
        WHEN duc.first_verified_enrollment_time IS NULL THEN DATEDIFF('day', duc.first_enrollment_time, NOW())
        ELSE DATEDIFF('day', duc.first_enrollment_time, duc.first_verified_enrollment_time)
    END AS duration,
    duc.first_verified_enrollment_time IS NOT NULL AS verified,
    COUNT(*)
FROM
(
    SELECT DISTINCT
        user_id,
        course_id,
        first_enrollment_time,
        first_verified_enrollment_time
    FROM production.d_user_course
) AS duc
JOIN
(
    SELECT DISTINCT
        course_id,
        course_start_date
    FROM business_intelligence.course_availability
    WHERE date = NOW()::DATE
) AS ca
    ON duc.course_id = ca.course_id
JOIN 
(
    SELECT DISTINCT
        course_id,
        course_partner,
        pacing_type,
        course_seat_price,
        course_verification_end_date,
        has_verification_deadline_passed,
        is_WL
    FROM
        business_intelligence.course_master
) AS c ON c.course_id = duc.course_id
WHERE
    ca.course_start_date > '2016-01-01'::DATE
    AND duc.first_enrollment_time < c.course_verification_end_date

GROUP BY 1, 2, 3, 4, 5, 6, 7
ORDER BY 1, 5, 2, 3, 4, 6, 7

"""

# %%
connection = vertica_python.connect(**conn_info)

cur = connection.cursor('dict')

cur.execute(query)
extract = cur.fetchall()
df = pd.DataFrame(extract)

connection.close()

# %%
df.groupby(['pacing_type', ])
# Out:
#             pacing_type  verified_after_enrollment  \
# 0      instructor_paced                      False
# 1      instructor_paced                      False
# 2      instructor_paced                      False
# 3      instructor_paced                      False
# 4      instructor_paced                      False
# 5      instructor_paced                      False
# 6      instructor_paced                      False
# 7      instructor_paced                      False
# 8      instructor_paced                       True
# 9      instructor_paced                       True
# 10     instructor_paced                       True
# 11     instructor_paced                       True
# 12     instructor_paced                       True
# 13     instructor_paced                       True
# 14     instructor_paced                       True
# 15     instructor_paced                       True
# 16     instructor_paced                       True
# 17     instructor_paced                       True
# 18     instructor_paced                       True
# 19     instructor_paced                       True
# 20     instructor_paced                       True
# 21     instructor_paced                       True
# 22     instructor_paced                       True
# 23     instructor_paced                       True
# 24     instructor_paced                       True
# 25     instructor_paced                       True
# 26     instructor_paced                       True
# 27     instructor_paced                       True
# 28     instructor_paced                       True
# 29     instructor_paced                       True
# ...                 ...                        ...
# 25653        self_paced                       True
# 25654        self_paced                       True
# 25655        self_paced                       True
# 25656        self_paced                       True
# 25657        self_paced                       True
# 25658        self_paced                       True
# 25659        self_paced                       True
# 25660        self_paced                       True
# 25661        self_paced                       True
# 25662        self_paced                       True
# 25663        self_paced                       True
# 25664        self_paced                       True
# 25665        self_paced                       True
# 25666        self_paced                       True
# 25667        self_paced                       True
# 25668        self_paced                       True
# 25669        self_paced                       True
# 25670        self_paced                       True
# 25671        self_paced                       True
# 25672        self_paced                       True
# 25673        self_paced                       True
# 25674        self_paced                       True
# 25675        self_paced                       True
# 25676        self_paced                       True
# 25677        self_paced                       True
# 25678        self_paced                       True
# 25679        self_paced                       True
# 25680        self_paced                       True
# 25681        self_paced                       True
# 25682        self_paced                       True
#
#       enrolled_before_course_start   is_microsoft               price  \
# 0                  > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 1                  > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 2                            After  Not Microsoft  1) 0 < price <= 25
# 3                            After  Not Microsoft  1) 0 < price <= 25
# 4                       First Week  Not Microsoft  1) 0 < price <= 25
# 5                       First Week  Not Microsoft  1) 0 < price <= 25
# 6                  One Week Before  Not Microsoft  1) 0 < price <= 25
# 7                  One Week Before  Not Microsoft  1) 0 < price <= 25
# 8                  > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 9                  > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 10                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 11                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 12                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 13                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 14                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 15                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 16                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 17                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 18                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 19                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 20                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 21                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 22                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 23                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 24                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 25                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 26                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 27                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 28                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# 29                 > 1 Week Before  Not Microsoft  1) 0 < price <= 25
# ...                            ...            ...                 ...
# 25653              One Week Before  Not Microsoft      4) 150 < price
# 25654              One Week Before  Not Microsoft      4) 150 < price
# 25655              One Week Before  Not Microsoft      4) 150 < price
# 25656              One Week Before  Not Microsoft      4) 150 < price
# 25657              One Week Before  Not Microsoft      4) 150 < price
# 25658              One Week Before  Not Microsoft      4) 150 < price
# 25659              One Week Before  Not Microsoft      4) 150 < price
# 25660              One Week Before  Not Microsoft      4) 150 < price
# 25661              One Week Before  Not Microsoft      4) 150 < price
# 25662              One Week Before  Not Microsoft      4) 150 < price
# 25663              One Week Before  Not Microsoft      4) 150 < price
# 25664              One Week Before  Not Microsoft      4) 150 < price
# 25665              One Week Before  Not Microsoft      4) 150 < price
# 25666              One Week Before  Not Microsoft      4) 150 < price
# 25667              One Week Before  Not Microsoft      4) 150 < price
# 25668              One Week Before  Not Microsoft      4) 150 < price
# 25669              One Week Before  Not Microsoft      4) 150 < price
# 25670              One Week Before  Not Microsoft      4) 150 < price
# 25671              One Week Before  Not Microsoft      4) 150 < price
# 25672              One Week Before  Not Microsoft      4) 150 < price
# 25673              One Week Before  Not Microsoft      4) 150 < price
# 25674              One Week Before  Not Microsoft      4) 150 < price
# 25675              One Week Before  Not Microsoft      4) 150 < price
# 25676              One Week Before  Not Microsoft      4) 150 < price
# 25677              One Week Before  Not Microsoft      4) 150 < price
# 25678              One Week Before  Not Microsoft      4) 150 < price
# 25679              One Week Before  Not Microsoft      4) 150 < price
# 25680              One Week Before  Not Microsoft      4) 150 < price
# 25681              One Week Before  Not Microsoft      4) 150 < price
# 25682              One Week Before  Not Microsoft      4) 150 < price
#
#        duration  verified  COUNT
# 0             0      True  17160
# 1             1      True     64
# 2             0      True   2318
# 3             1      True      8
# 4             0      True   4020
# 5             1      True     10
# 6             0      True   5944
# 7             1      True     40
# 8             0      True   1222
# 9             1      True    940
# 10            2      True    452
# 11            3     False    296
# 12            3      True    298
# 13            4     False    666
# 14            4      True    292
# 15            5     False   1008
# 16            5      True    266
# 17            6     False   1934
# 18            6      True    276
# 19            7     False    862
# 20            7      True    272
# 21            8     False    796
# 22            8      True    272
# 23            9     False    128
# 24            9      True    256
# 25           10     False    158
# 26           10      True    198
# 27           11     False    292
# 28           11      True    194
# 29           12     False    382
# ...         ...       ...    ...
# 25653       117      True      2
# 25654       120     False    118
# 25655       121     False     94
# 25656       122     False     58
# 25657       123     False    114
# 25658       124     False    110
# 25659       125     False     92
# 25660       126     False    116
# 25661       127     False     50
# 25662       142     False    688
# 25663       143     False    532
# 25664       144     False    682
# 25665       145     False    716
# 25666       146     False    618
# 25667       147     False    468
# 25668       148     False    402
# 25669       183     False    148
# 25670       184     False    138
# 25671       185     False    128
# 25672       186     False    316
# 25673       187     False    164
# 25674       188     False     96
# 25675       189     False     84
# 25676       191     False     92
# 25677       192     False     94
# 25678       193     False    168
# 25679       194     False    118
# 25680       195     False    106
# 25681       196     False    108
# 25682       197     False     58
#
# [25683 rows x 8 columns]
